# %% [raw]
# primeira vez em jupyter e mineconda

# %% [markdown]
# # Meu primeiro dia usando markdown beijocas

# %%
# revisão
nome = 'joaquim'
idade = 34
valor_em_carteira = 345.99
vip = True # false
nome = 99 + 1
print(nome)
# Out:
# 100

# %%
def soma_de_valores(valor1, valor2):
    resultado = valor1 + valor2
    return resultado


valor1 = 20
valor2 = 18

soma = soma_de_valores(valor1, valor2)
print(soma)
# Out:
# 38

# %%
lista_de_clientes = ["pedro", "pablo", "solange", "alvarez"]
lista_de_itens = ["banana", "mala", "carro", "sirene"]
print(lista_de_clientes)

lista_de_clientes.append("julia")

print(lista_de_clientes)
lista_de_clientes[4]
# Out:
# ['pedro', 'pablo', 'solange', 'alvarez']
# ['pedro', 'pablo', 'solange', 'alvarez', 'julia']
# 'julia'

# %%
#tupla
lista_de_vendas=[]
venda = ("banana",4,8.0)
lista_de_vendas.append(venda)
print(lista_de_vendas)
# Out:
# [('banana', 4, 8.0)]

# %%
cliente1 ={
    "nome": "pedro",
    "idade": 23,
    "vip": True,
    "carteira":10000000000000000000000,
}

cliente2 ={
    "nome":"lagie",
    "idade":32,
    "vip": False,
    "carteira":200000000000,
}

cliente1 ["idade"] = 25
lista_de_clientes = (cliente1,cliente2)
print(cliente1["carteira"])
# Out:
# 10000000000000000000000

# %%
import math
print(math.sqrt(4))
# Out:
# 2.0
